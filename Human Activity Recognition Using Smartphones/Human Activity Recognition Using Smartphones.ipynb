# %% [markdown]
# # Human Activity Recognition Using Smartphones
#
# **Abstract:** In this project, we calculate a model by which a smartphone can detect its owner’s activity precisely. For the dataset, 30 people were used to perform 6 different activities. Each of them was wearing a Samsung Galaxy SII on their waist. Using the smartphone’s embedded sensors (the accelerometer and the gyroscope), the user’s speed and acceleration were measured in 3-axial directions. We use the sensor’s data to predict user’s activity. The experiments have been video-recorded to label the data manually. The obtained dataset has been randomly partitioned into two sets, where 70% of the volunteers was selected for generating the training data and 30% the test data.
#
# The sensor signals (accelerometer and gyroscope) were pre-processed by applying noise filters and then sampled in fixed-width sliding windows of 2.56 sec and 50% overlap (128 readings/window). The sensor acceleration signal, which has gravitational and body motion components, was separated using a Butterworth low-pass filter into body acceleration and gravity. The gravitational force is assumed to have only low frequency components, therefore a filter with 0.3 Hz cutoff frequency was used. From each window, a vector of features was obtained by calculating variables from the time and frequency domain.
#
# Attribute information
# - For each record in the dataset the following is provided:
# - Triaxial acceleration from the accelerometer (total acceleration) and the estimated body acceleration.
# - Triaxial Angular velocity from the gyroscope.
# - A 561-feature vector with time and frequency domain variables.
# - Its activity label.
# - An identifier of the subject who carried out the experiment.
#
#
# ## Overall Information
# Project’s Website: http://archive.ics.uci.edu/ml/datasets/Human+Activity+Recognition+Using+Smartphones
#
# Data Sources: https://www.kaggle.com/uciml/human-activity-recognition-with-smartphones
#
# **Highest Achieved precision:** 98.8%
#
# **Goal:** In this project we will try to predict human activity (1-Walking, 2-Walking upstairs, 3-Walking downstairs, 4-Sitting, 5-Standing or 6-Laying) by using the smartphone’s sensors. Meaning that by using the following methods, the smartphone can detect what we are doing at the moment.
#
# ## Citation
#
# *Davide Anguita, Alessandro Ghio, Luca Oneto, Xavier Parra and Jorge L. Reyes-Ortiz. A Public Domain Dataset for Human Activity Recognition Using Smartphones. 21st European Symposium on Artificial Neural Networks, Computational Intelligence and Machine Learning, ESANN 2013. Bruges, Belgium 24-26 April 2013.*

# %% [markdown]
# # Libraries

# %%
# python 3 environment
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O

# plotly Libraris
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.colors import n_colors
from plotly.subplots import make_subplots

# pycaret for classification
from pycaret.classification import *

# %% [markdown]
# # Step 1: Create Uniform Data From Data Set
#
# We have two datasets for the training data and its corresponding labels, and two datasets for the test data and its corresponding labels. The following code will combine these datasets for further machine learning procedure.

# %%
ROOT = '../Human Activity Recognition Using Smartphones/Data Sources/'
train = pd.read_csv(ROOT+'train.csv')
test = pd.read_csv(ROOT+'test.csv')

# %%
data = pd.concat([train,test]); data.head(7)
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# 1            -0.998245         -0.975300         -0.960322         -0.998807
# 2            -0.995380         -0.967187         -0.978944         -0.996520
# 3            -0.996091         -0.983403         -0.990675         -0.997099
# 4            -0.998139         -0.980817         -0.990482         -0.998321
# ...                ...               ...               ...               ...
# 2942         -0.287866         -0.140589         -0.215088         -0.356083
# 2943         -0.305388          0.028148         -0.196373         -0.373540
# 2944         -0.329638         -0.042143         -0.250181         -0.388017
# 2945         -0.323114         -0.229775         -0.207574         -0.392380
# 2946         -0.330046         -0.195253         -0.164339         -0.430974
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 0            -0.983185         -0.923527         -0.934724  ...
# 1            -0.974914         -0.957686         -0.943068  ...
# 2            -0.963668         -0.977469         -0.938692  ...
# 3            -0.982750         -0.989302         -0.938692  ...
# 4            -0.979672         -0.990441         -0.942469  ...
# ...                ...               ...               ...  ...
# 2942         -0.148775         -0.232057          0.185361  ...
# 2943         -0.030036         -0.270237          0.185361  ...
# 2944         -0.133257         -0.347029          0.007471  ...
# 2945         -0.279610         -0.289477          0.007471  ...
# 2946         -0.218295         -0.229933         -0.111527  ...
#
#       fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                           -0.710304                    -0.112754
# 1                           -0.861499                     0.053477
# 2                           -0.760104                    -0.118559
# 3                           -0.482845                    -0.036788
# 4                           -0.699205                     0.123320
# ...                               ...                          ...
# 2942                        -0.750809                    -0.337422
# 2943                        -0.700274                    -0.736701
# 2944                        -0.467179                    -0.181560
# 2945                        -0.617737                     0.444558
# 2946                        -0.436940                     0.598808
#
#       angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                                 0.030400                         -0.464761
# 1                                -0.007435                         -0.732626
# 2                                 0.177899                          0.100699
# 3                                -0.012892                          0.640011
# 4                                 0.122542                          0.693578
# ...                                    ...                               ...
# 2942                              0.346295                          0.884904
# 2943                             -0.372889                         -0.657421
# 2944                              0.088574                          0.696663
# 2945                             -0.819188                          0.929294
# 2946                             -0.287951                          0.876030
#
#       angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                                -0.018446             -0.841247
# 1                                 0.703511             -0.844788
# 2                                 0.808529             -0.848933
# 3                                -0.485366             -0.848649
# 4                                -0.615971             -0.847865
# ...                                    ...                   ...
# 2942                             -0.698885             -0.651732
# 2943                              0.322549             -0.655181
# 2944                              0.363139             -0.655357
# 2945                             -0.008398             -0.659719
# 2946                             -0.024965             -0.660080
#
#       angle(Y,gravityMean)  angle(Z,gravityMean)  subject          Activity
# 0                 0.179941             -0.058627        1          STANDING
# 1                 0.180289             -0.054317        1          STANDING
# 2                 0.180637             -0.049118        1          STANDING
# 3                 0.181935             -0.047663        1          STANDING
# 4                 0.185151             -0.043892        1          STANDING
# ...                    ...                   ...      ...               ...
# 2942              0.274627              0.184784       24  WALKING_UPSTAIRS
# 2943              0.273578              0.182412       24  WALKING_UPSTAIRS
# 2944              0.274479              0.181184       24  WALKING_UPSTAIRS
# 2945              0.264782              0.187563       24  WALKING_UPSTAIRS
# 2946              0.263936              0.188103       24  WALKING_UPSTAIRS
#
# [10299 rows x 563 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10299 entries, 0 to 2946
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 44.3+ MB

# %% [markdown]
# # Step 2: Preprocessing

# %%
def preprocessing(data):
    for column in data.columns:
        if data.dtypes[column] == 'float64':
            data[column] = data[column].astype('float32')
        if data.dtypes[column] == 'object':
            data[column] = data[column].astype('category')
    return data

# %%
data = data.drop('subject', axis=1)
preprocessing(data)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10299 entries, 0 to 2946
# Columns: 562 entries, tBodyAcc-mean()-X to Activity
# dtypes: category(1), float32(561)
# memory usage: 22.1 MB

# %% [markdown]
# # Step 3: Model

# %% [markdown]
# ## 3.1 Setting up Environment
# This function initializes the environment in pycaret and creates the transformation pipeline to prepare the data for modeling and deployment.

# %%
setup(data, 
      target='Activity', 
      normalize=True, 
      transformation=True, 
      session_id=707,
      sampling=False, 
      silent=True);

# %% [markdown]
# ## 3.2 Compare Models¶
# This function uses models in the model library and scores them using K-fold Cross Validation. The output prints a score grid with Accuracy, AUC, Recall, Precision, F1, Kappa and MCC (averaged accross folds), determined by fold parameter.

# %%
compare_models(whitelist=['lr', 'ridge', 'xgboost']) #catboost is slightly better but require way too much computational time in this context
# Out:
# <style  type="text/css" >
#     #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54 th {
#           text-align: left;
#     }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col0 {
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col2 {
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col7 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col0 {
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col2 {
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col7 {
#             : ;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col0 {
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col2 {
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col7 {
#             : ;
#             text-align:  left;
#         }    #T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }</style><table id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col1" class="data row0 col1" >0.9903</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col2" class="data row0 col2" >0.0000</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col3" class="data row0 col3" >0.9906</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col4" class="data row0 col4" >0.9904</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col5" class="data row0 col5" >0.9903</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col6" class="data row0 col6" >0.9883</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col7" class="data row0 col7" >0.9883</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row0_col8" class="data row0 col8" >32.6213</td>
#             </tr>
#             <tr>
#                         <th id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col0" class="data row1 col0" >Logistic Regression</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col1" class="data row1 col1" >0.9816</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col2" class="data row1 col2" >0.0000</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col3" class="data row1 col3" >0.9824</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col4" class="data row1 col4" >0.9817</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col5" class="data row1 col5" >0.9815</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col6" class="data row1 col6" >0.9778</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col7" class="data row1 col7" >0.9778</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row1_col8" class="data row1 col8" >2.3590</td>
#             </tr>
#             <tr>
#                         <th id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col0" class="data row2 col0" >Ridge Classifier</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col1" class="data row2 col1" >0.9784</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col2" class="data row2 col2" >0.0000</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col3" class="data row2 col3" >0.9792</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col4" class="data row2 col4" >0.9785</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col5" class="data row2 col5" >0.9783</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col6" class="data row2 col6" >0.9740</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col7" class="data row2 col7" >0.9740</td>
#                         <td id="T_6f7f109c_e0b1_11ea_a403_a0a7ebb52c54row2_col8" class="data row2 col8" >0.4328</td>
#             </tr>
#     </tbody></table>
# OneVsRestClassifier(estimator=XGBClassifier(base_score=None, booster=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, gamma=None,
#                                             gpu_id=None, importance_type='gain',
#                                             interaction_constraints=None,
#                                             learning_rate=None,
#                                             max_delta_step=None, max_depth=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             n_estimators=100, n_jobs=-1,
#                                             num_parallel_tree=None,
#                                             objective='binary:logistic',
#                                             random_state=707, reg_alpha=None,
#                                             reg_lambda=None,
#                                             scale_pos_weight=None,
#                                             subsample=None, tree_method=None,
#                                             validate_parameters=None,
#                                             verbosity=0),
#                     n_jobs=-1)

# %% [markdown]
# ## 3.3 Create Model
# This function creates a model and scores it using K-fold Cross Validation.

# %%
model = create_model('xgboost', ensemble=True, method='Bagging') #0 is gpu-id
# Out:
# <style  type="text/css" >
#     #T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row10_col0 {
#             background:  yellow;
#         }    #T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row10_col1 {
#             background:  yellow;
#         }    #T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row10_col2 {
#             background:  yellow;
#         }    #T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row10_col3 {
#             background:  yellow;
#         }    #T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row10_col4 {
#             background:  yellow;
#         }    #T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row10_col5 {
#             background:  yellow;
#         }    #T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row10_col6 {
#             background:  yellow;
#         }</style><table id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row0_col0" class="data row0 col0" >0.9875</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row0_col1" class="data row0 col1" >0.0000</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row0_col2" class="data row0 col2" >0.9868</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row0_col3" class="data row0 col3" >0.9875</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row0_col4" class="data row0 col4" >0.9875</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row0_col5" class="data row0 col5" >0.9850</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row0_col6" class="data row0 col6" >0.9850</td>
#             </tr>
#             <tr>
#                         <th id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row1_col0" class="data row1 col0" >0.9875</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row1_col1" class="data row1 col1" >0.0000</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row1_col2" class="data row1 col2" >0.9883</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row1_col3" class="data row1 col3" >0.9875</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row1_col4" class="data row1 col4" >0.9875</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row1_col5" class="data row1 col5" >0.9850</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row1_col6" class="data row1 col6" >0.9850</td>
#             </tr>
#             <tr>
#                         <th id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row2_col0" class="data row2 col0" >0.9847</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row2_col1" class="data row2 col1" >0.0000</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row2_col2" class="data row2 col2" >0.9850</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row2_col3" class="data row2 col3" >0.9847</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row2_col4" class="data row2 col4" >0.9847</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row2_col5" class="data row2 col5" >0.9816</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row2_col6" class="data row2 col6" >0.9816</td>
#             </tr>
#             <tr>
#                         <th id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row3_col0" class="data row3 col0" >0.9861</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row3_col1" class="data row3 col1" >0.0000</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row3_col2" class="data row3 col2" >0.9870</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row3_col3" class="data row3 col3" >0.9862</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row3_col4" class="data row3 col4" >0.9861</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row3_col5" class="data row3 col5" >0.9833</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row3_col6" class="data row3 col6" >0.9833</td>
#             </tr>
#             <tr>
#                         <th id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row4_col0" class="data row4 col0" >0.9889</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row4_col1" class="data row4 col1" >0.0000</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row4_col2" class="data row4 col2" >0.9892</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row4_col3" class="data row4 col3" >0.9890</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row4_col4" class="data row4 col4" >0.9889</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row4_col5" class="data row4 col5" >0.9867</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row4_col6" class="data row4 col6" >0.9867</td>
#             </tr>
#             <tr>
#                         <th id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row5_col0" class="data row5 col0" >0.9861</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row5_col1" class="data row5 col1" >0.0000</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row5_col2" class="data row5 col2" >0.9866</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row5_col3" class="data row5 col3" >0.9861</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row5_col4" class="data row5 col4" >0.9861</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row5_col5" class="data row5 col5" >0.9833</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row5_col6" class="data row5 col6" >0.9833</td>
#             </tr>
#             <tr>
#                         <th id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row6_col0" class="data row6 col0" >0.9903</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row6_col1" class="data row6 col1" >0.0000</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row6_col2" class="data row6 col2" >0.9903</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row6_col3" class="data row6 col3" >0.9904</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row6_col4" class="data row6 col4" >0.9903</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a0a7ebb52c54row6_col5" class="data row6 col5" >0.9883</td>
#                         <td id="T_6c179588_e0b9_11ea_8f60_a

# %% [markdown]
# ## 3.4 Finalize Model
# This function fits the estimator onto the complete dataset passed during the setup() stage. The purpose of this function is to prepare for final model deployment after experimentation.

# %%
final_model = finalize_model(model)

# %% [markdown]
# ## 3.5 Model Evaluation
# This function displays a user interface for all of the available plots for a given estimator. It internally uses the plot_model() function.

# %%
evaluate_model(final_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
